# %%
import pandas as pd
import numpy as np
import seaborn as sns

#importing pandas as pd

# %%
data=pd.read_csv("C:/Users/MYLAR/Downloads/shootings.csv",index_col=0)
data['date']=pd.to_datetime(data['date'],format="%m %d %Y")
data
# Out:
#                     name       date   manner_of_death       armed   age  \
# id
# 3             Tim Elliot 2015-01-02              shot         gun  53.0
# 4       Lewis Lee Lembke 2015-01-02              shot         gun  47.0
# 5     John Paul Quintero 2015-01-03  shot and Tasered     unarmed  23.0
# 8        Matthew Hoffman 2015-01-04              shot  toy weapon  32.0
# 9      Michael Rodriguez 2015-01-04              shot    nail gun  39.0
# ...                  ...        ...               ...         ...   ...
# 5916     Rayshard Brooks 2020-06-12              shot       Taser  27.0
# 5925      Caine Van Pelt 2020-06-12              shot         gun  23.0
# 5918        Hannah Fizer 2020-06-13              shot     unarmed  25.0
# 5921      William Slyter 2020-06-13              shot         gun  22.0
# 5924      Nicholas Hirsh 2020-06-15              shot         gun  31.0
#
#      gender      race           city state  signs_of_mental_illness  \
# id
# 3         M     Asian        Shelton    WA                     True
# 4         M     White          Aloha    OR                    False
# 5         M  Hispanic        Wichita    KS                    False
# 8         M     White  San Francisco    CA                     True
# 9         M  Hispanic          Evans    CO                    False
# ...     ...       ...            ...   ...                      ...
# 5916      M     Black        Atlanta    GA                    False
# 5925      M     Black    Crown Point    IN                    False
# 5918      F     White        Sedalia    MO                    False
# 5921      M     White    Kansas City    MO                    False
# 5924      M     White       Lawrence    KS                    False
#
#      threat_level         flee  body_camera          arms_category
# id
# 3          attack  Not fleeing        False                   Guns
# 4          attack  Not fleeing        False                   Guns
# 5           other  Not fleeing        False                Unarmed
# 8          attack  Not fleeing        False  Other unusual objects
# 9          attack  Not fleeing        False       Piercing objects
# ...           ...          ...          ...                    ...
# 5916       attack         Foot         True     Electrical devices
# 5925       attack          Car        False                   Guns
# 5918        other  Not fleeing        False                Unarmed
# 5921        other        Other        False                   Guns
# 5924       attack          Car        False                   Guns
#
# [4895 rows x 14 columns]

# %%
data.head()
# Out:
#                   name       date   manner_of_death       armed   age gender  \
# id
# 3           Tim Elliot 2015-01-02              shot         gun  53.0      M
# 4     Lewis Lee Lembke 2015-01-02              shot         gun  47.0      M
# 5   John Paul Quintero 2015-01-03  shot and Tasered     unarmed  23.0      M
# 8      Matthew Hoffman 2015-01-04              shot  toy weapon  32.0      M
# 9    Michael Rodriguez 2015-01-04              shot    nail gun  39.0      M
#
#         race           city state  signs_of_mental_illness threat_level  \
# id
# 3      Asian        Shelton    WA                     True       attack
# 4      White          Aloha    OR                    False       attack
# 5   Hispanic        Wichita    KS                    False        other
# 8      White  San Francisco    CA                     True       attack
# 9   Hispanic          Evans    CO                    False       attack
#
#            flee  body_camera          arms_category
# id
# 3   Not fleeing        False                   Guns
# 4   Not fleeing        False                   Guns
# 5   Not fleeing        False                Unarmed
# 8   Not fleeing        False  Other unusual objects
# 9   Not fleeing        False       Piercing objects

# %%
data.shape
#This shows the number of rows and columns in our data
# Out:
# (4895, 14)

# %% [markdown]
# # BASIC ANALYSIS

# %%
data.gender.value_counts()
#This shows the number of males and females who were killed
# Out:
# M    4673
# F     222
# Name: gender, dtype: int64

# %%
data.race.value_counts()
# Out:
# White       2476
# Black       1298
# Hispanic     902
# Asian         93
# Native        78
# Other         48
# Name: race, dtype: int64

# %%
data.manner_of_death.value_counts()
#This shows number of people who died through a particular manner of death
# Out:
# shot                4647
# shot and Tasered     248
# Name: manner_of_death, dtype: int64

# %%
data.armed.value_counts()
#This shows the number of people who were armed with a particular weapon
# Out:
# gun                       2755
# knife                      708
# unknown                    418
# unarmed                    348
# toy weapon                 171
#                           ...
# bayonet                      1
# nail gun                     1
# gun and sword                1
# car, knife and mace          1
# baseball bat and knife       1
# Name: armed, Length: 89, dtype: int64

# %%
data.signs_of_mental_illness.value_counts()
#the number of people who showed and did not show signs of mental illness
# Out:
# False    3792
# True     1103
# Name: signs_of_mental_illness, datatype: int 64

# %%
data.body_camera.value_counts()
#Number of killings which were recorded.
# Out:
# False    4317
# True      578
# Name: body_camera, datatype: int 64

# %% [markdown]
# # which race had the highest number of killings?.How many men and women were killed under a specific race?

# %%
sns.countplot(x='race',data=data, hue="gender",palette='bwr');

# %% [markdown]
# # what is the age distribution of killings based in gender?

# %%
sns.histplot(data=data, x='age',hue='gender',palette='bwr');

# %% [markdown]
# # which state recorded the highest number of killings?.

# %%
sns.countplot(x='state',data=data,);
sns.set(rc={'figure.figsize':(20,12)})

# %% [markdown]
# # The city with the heighest shooting

# %%
h_shotCity=data.city.value_counts(ascending=False)
h_shotCity.head()
# Out:
# Los Angeles    78
# Phoenix        66
# Houston        51
# Las Vegas      41
# San Antonio    40
# Name: city, dtype: int64

# %%
h_shotCity.head().plot(kind='bar',color='orange')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Threats level of Race and Arms category used

# %%
#threat level from  race #unsorted_well
level=data.groupby(['race','arms_category']).threat_level.agg([len,min ]).sort_values(by='len',ascending =False)
level
# Out:
#                                  len     min
# race     arms_category
# White    Guns                   1455  attack
# Black    Guns                    766  attack
# Hispanic Guns                    448  attack
# White    Sharp objects           395  attack
#          Unknown                 200  attack
# Hispanic Sharp objects           189  attack
# Black    Sharp objects           170  attack
# White    Unarmed                 146  attack
# Black    Unarmed                 123  attack
#          Unknown                 108  attack
# White    Other unusual objects   106  attack
# Hispanic Unknown                  89  attack
# White    Blunt instruments        65  attack
# Hispanic Unarmed                  63  attack
# White    Vehicles                 58  attack
# Black    Other unusual objects    43  attack
#          Vehicles                 43  attack
# Native   Guns                     41  attack
# Hispanic Other unusual objects    40  attack
# Asian    Guns                     35  attack
#          Sharp objects            31  attack
# Hispanic Blunt instruments        30  attack
# White    Multiple                 25  attack
# Black    Blunt instruments        20  attack
# Other    Guns                     19  attack
# Native   Sharp objects            19  attack
# Hispanic Vehicles                 17  attack
# White    Piercing objects         14  attack
# Other    Sharp objects            14  attack
# Hispanic Multiple                 13  attack
# Black    Multiple                 11  attack
# White    Electrical devices       10  attack
# Black    Electrical devices        9  attack
# Hispanic Piercing objects          8  attack
# Asian    Unknown                   8  attack
# Native   Unknown                   8  attack
# Asian    Unarmed                   7  attack
# Other    Unknown                   5   other
#          Unarmed                   5  attack
# Asian    Blunt instruments         5  attack
# Black    Piercing objects          4  attack
# Native   Unarmed                   4  attack
# Hispanic Electrical devices        4  attack
# Asian    Multiple                  3  attack
# Native   Blunt instruments         2  attack
# Asian    Other unusual objects     2   other
# Other    Multiple                  2  attack
# White    Explosives                2  attack
# Other    Vehicles                  2  attack
# Native   Electrical devices        1  attack
# Asian    Explosives                1   other
# Hispanic Explosives                1   other
# Asian    Piercing objects          1  attack
# Native   Other unusual objects     1  attack
#          Piercing objects          1   other
# Other    Piercing objects          1   other
# Black    Hand tools                1   other
# Native   Vehicles                  1  attack

# %%
#Threats level of Race and Arms category used
level.reset_index().sort_values(by='race',ascending =False)
# Out:
#         race          arms_category   len     min
# 0      White                   Guns  1455  attack
# 10     White  Other unusual objects   106  attack
# 27     White       Piercing objects    14  attack
# 22     White               Multiple    25  attack
# 31     White     Electrical devices    10  attack
# 14     White               Vehicles    58  attack
# 47     White             Explosives     2  attack
# 12     White      Blunt instruments    65  attack
# 7      White                Unarmed   146  attack
# 3      White          Sharp objects   395  attack
# 4      White                Unknown   200  attack
# 24     Other                   Guns    19  attack
# 55     Other       Piercing objects     1   other
# 46     Other               Multiple     2  attack
# 28     Other          Sharp objects    14  attack
# 48     Other               Vehicles     2  attack
# 38     Other                Unarmed     5  attack
# 37     Other                Unknown     5   other
# 35    Native                Unknown     8  attack
# 49    Native     Electrical devices     1  attack
# 44    Native      Blunt instruments     2  attack
# 54    Native       Piercing objects     1   other
# 25    Native          Sharp objects    19  attack
# 53    Native  Other unusual objects     1  attack
# 41    Native                Unarmed     4  attack
# 57    Native               Vehicles     1  attack
# 17    Native                   Guns    41  attack
# 26  Hispanic               Vehicles    17  attack
# 18  Hispanic  Other unusual objects    40  attack
# 2   Hispanic                   Guns   448  attack
# 5   Hispanic          Sharp objects   189  attack
# 51  Hispanic             Explosives     1   other
# 11  Hispanic                Unknown    89  attack
# 13  Hispanic                Unarmed    63  attack
# 42  Hispanic     Electrical devices     4  attack
# 29  Hispanic               Multiple    13  attack
# 33  Hispanic       Piercing objects     8  attack
# 21  Hispanic      Blunt instruments    30  attack
# 9      Black                Unknown   108  attack
# 56     Black             Hand tools     1   other
# 1      Black                   Guns   766  attack
# 6      Black          Sharp objects   170  attack
# 30     Black               Multiple    11  attack
# 8      Black                Unarmed   123  attack
# 32     Black     Electrical devices     9  attack
# 15     Black  Other unusual objects    43  attack
# 23     Black      Blunt instruments    20  attack
# 16     Black               Vehicles    43  attack
# 40     Black       Piercing objects     4  attack
# 45     Asian  Other unusual objects     2   other
# 36     Asian                Unarmed     7  attack
# 20     Asian          Sharp objects    31  attack
# 43     Asian               Multiple     3  attack
# 50     Asian             Explosives     1   other
# 52     Asian       Piercing objects     1  attack
# 39     Asian      Blunt instruments     5  attack
# 34     Asian                Unknown     8  attack
# 19     Asian                   Guns    35  attack

# %% [markdown]
# # Age grouping of Shootings

# %%
#18 and above
over18=data.loc[data.age>=18]
over18
# Out:
#                     name       date   manner_of_death       armed   age  \
# id
# 3             Tim Elliot 2015-01-02              shot         gun  53.0
# 4       Lewis Lee Lembke 2015-01-02              shot         gun  47.0
# 5     John Paul Quintero 2015-01-03  shot and Tasered     unarmed  23.0
# 8        Matthew Hoffman 2015-01-04              shot  toy weapon  32.0
# 9      Michael Rodriguez 2015-01-04              shot    nail gun  39.0
# ...                  ...        ...               ...         ...   ...
# 5916     Rayshard Brooks 2020-06-12              shot       Taser  27.0
# 5925      Caine Van Pelt 2020-06-12              shot         gun  23.0
# 5918        Hannah Fizer 2020-06-13              shot     unarmed  25.0
# 5921      William Slyter 2020-06-13              shot         gun  22.0
# 5924      Nicholas Hirsh 2020-06-15              shot         gun  31.0
#
#      gender      race           city state  signs_of_mental_illness  \
# id
# 3         M     Asian        Shelton    WA                     True
# 4         M     White          Aloha    OR                    False
# 5         M  Hispanic        Wichita    KS                    False
# 8         M     White  San Francisco    CA                     True
# 9         M  Hispanic          Evans    CO                    False
# ...     ...       ...            ...   ...                      ...
# 5916      M     Black        Atlanta    GA                    False
# 5925      M     Black    Crown Point    IN                    False
# 5918      F     White        Sedalia    MO                    False
# 5921      M     White    Kansas City    MO                    False
# 5924      M     White       Lawrence    KS                    False
#
#      threat_level         flee  body_camera          arms_category
# id
# 3          attack  Not fleeing        False                   Guns
# 4          attack  Not fleeing        False                   Guns
# 5           other  Not fleeing        False                Unarmed
# 8          attack  Not fleeing        False  Other unusual objects
# 9          attack  Not fleeing        False       Piercing objects
# ...           ...          ...          ...                    ...
# 5916       attack         Foot         True     Electrical devices
# 5925       attack          Car        False                   Guns
# 5918        other  Not fleeing        False                Unarmed
# 5921        other        Other        False                   Guns
# 5924       attack          Car        False                   Guns
#
# [4798 rows x 14 columns]

# %%
#under 18
under18=data.loc[data.age<=17]
under18
# Out:
#                          name       date   manner_of_death    armed   age  \
# id
# 100        Kristiana Coignard 2015-01-22  shot and Tasered    knife  17.0
# 20           Jessie Hernandez 2015-01-26              shot  unknown  17.0
# 528             Jacob Haglund 2015-02-02              shot      gun  17.0
# 149          Jason C. Hendrix 2015-02-14              shot      gun  16.0
# 176        A'Donte Washington 2015-02-23              shot      gun  16.0
# ...                       ...        ...               ...      ...   ...
# 5495               Alvin Cole 2020-02-02              shot      gun  17.0
# 5536              Daelyn Polu 2020-02-15              shot      gun  16.0
# 5556            Joseph Jewell 2020-02-20              shot      gun  17.0
# 5592             Dylan Olmeda 2020-02-25              shot      gun  16.0
# 5733  Joshua Dariandre Ruffin 2020-04-08              shot      gun  17.0
#
#      gender      race        city state  signs_of_mental_illness threat_level  \
# id
# 100       F     White    Longview    TX                     True        other
# 20        F  Hispanic      Denver    CO                    False        other
# 528       M     White    Bay City    MI                    False       attack
# 149       M     White       Essex    MD                     True       attack
# 176       M     Black   Millbrook    AL                    False       attack
# ...     ...       ...         ...   ...                      ...          ...
# 5495      M     Black   Wauwatosa    WI                    False       attack
# 5536      M     Asian    Achorage    AK                    False       attack
# 5556      M     Black    Columbus    OH                    False       attack
# 5592      M     White  Georgetown    TX                    False       attack
# 5733      M     Black    Columbia    SC                    False        other
#
#              flee  body_camera  arms_category
# id
# 100   Not fleeing        False  Sharp objects
# 20    Not fleeing        False        Unknown
# 528   Not fleeing        False           Guns
# 149           Car        False           Guns
# 176   Not fleeing        False           Guns
# ...           ...          ...            ...
# 5495         Foot        False           Guns
# 5536  Not fleeing        False           Guns
# 5556  Not fleeing        False           Guns
# 5592  Not fleeing        False           Guns
# 5733         Foot        False           Guns
#
# [97 rows x 14 columns]

# %% [markdown]
# # shootings grouped by Ages and Gender

# %%
#under 18 years
under18.groupby(['gender']).manner_of_death.agg([len,min,max]).sort_values(by='len',ascending =False)
# Out:
#         len   min               max
# gender
# M        90  shot  shot and Tasered
# F         7  shot  shot and Tasered

# %%
#over 18 years
over18.groupby(['gender']).manner_of_death.agg([len,min,max]).sort_values(by='len',ascending =False)
# Out:
#          len   min               max
# gender
# M       4583  shot  shot and Tasered
# F        215  shot  shot and Tasered

# %% [markdown]
# # Grouping of Shootings by Year

# %%
shot_2015=data.loc[data['date']<='2015-12-31']
shot_2020=data.loc[(data['date']>'2019-12-31')&(data['date']<='2020-12-31')]
shot_2016=data.loc[(data['date']>'2015-12-31')&(data['date']<='2016-12-31')]
shot_2017=data.loc[(data['date']>'2016-12-31')&(data['date']<='2017-12-31')]
shot_2018=data.loc[(data['date']>'2017-12-31')&(data['date']<='2018-12-31')]
shot_2019=data.loc[(data['date']>'2018-12-31')&(data['date']<='2019-12-31')]

# %%
#shot_2015

#shot_2016

#shot_2017

#shot_2018

#shot_2019

shot_2020
# Out:
#                                 name       date   manner_of_death       armed  \
# id
# 5344               Derrick A. Elseth 2020-01-01              shot         gun
# 5403  Gerardo Antonio Conchas-Bustas 2020-01-01              shot       knife
# 5342              Gabriel Strickland 2020-01-01  shot and Tasered  toy weapon
# 5339            Jeffery Dale Millsap 2020-01-02              shot         gun
# 5349            Jamari Daiwon Tarver 2020-01-02              shot     vehicle
# ...                              ...        ...               ...         ...
# 5916                 Rayshard Brooks 2020-06-12              shot       Taser
# 5925                  Caine Van Pelt 2020-06-12              shot         gun
# 5918                    Hannah Fizer 2020-06-13              shot     unarmed
# 5921                  William Slyter 2020-06-13              shot         gun
# 5924                  Nicholas Hirsh 2020-06-15              shot         gun
#
#        age gender   race             city state  signs_of_mental_illness  \
# id
# 5344  24.0      M  White  Richmond County    VA                    False
# 5403  20.0      M  Other           Denver    CO                    False
# 5342  25.0      M  White     Grass Valley    CA                     True
# 5339  26.0      M  White             Holt    MO                    False
# 5349  26.0      M  Black  North Las Vegas    NV                    False
# ...    ...    ...    ...              ...   ...                      ...
# 5916  27.0      M  Black          Atlanta    GA                    False
# 5925  23.0      M  Black      Crown Point    IN                    False
# 5918  25.0      F  White          Sedalia    MO                    False
# 5921  22.0      M  White      Kansas City    MO                    False
# 5924  31.0      M  White         Lawrence    KS                    False
#
#      threat_level         flee  body_camera          arms_category
# id
# 5344        other  Not fleeing        False                   Guns
# 5403       attack  Not fleeing         True          Sharp objects
# 5342       attack  Not fleeing        False  Other unusual objects
# 5339       attack          Car        False                   Guns
# 5349       attack          Car         True               Vehicles
# ...           ...          ...          ...                    ...
# 5916       attack         Foot         True     Electrical devices
# 5925       attack          Car        False                   Guns
# 5918        other  Not fleeing        False                Unarmed
# 5921        other        Other        False                   Guns
# 5924       attack          Car        False                   Guns
#
# [374 rows x 14 columns]

# %% [markdown]
# # Number of Shootings of Race Per Each Year

# %%
                            #YEARS
#shot_2015.groupby(['race']).manner_of_death.agg([len,min,max]).sort_values(by='len',ascending =False)



#shot_2016.groupby(['race']).manner_of_death.agg([len,min,max]).sort_values(by='len',ascending =False)



#shot_2017.groupby(['race']).manner_of_death.agg([len,min,max]).sort_values(by='len',ascending =False)



#shot_2018.groupby(['race']).manner_of_death.agg([len,min,max]).sort_values(by='len',ascending =False)


#shot_2019.groupby(['race']).manner_of_death.agg([len,min,max]).sort_values(by='len',ascending =False)



shot_2020.groupby(['race']).manner_of_death.agg([len,min,max]).sort_values(by='len',ascending =False)
# Out:
#           len   min               max
# race
# White     194  shot  shot and Tasered
# Black     103  shot  shot and Tasered
# Hispanic   63  shot  shot and Tasered
# Asian       8  shot  shot and Tasered
# Native      3  shot              shot
# Other       3  shot              shot
